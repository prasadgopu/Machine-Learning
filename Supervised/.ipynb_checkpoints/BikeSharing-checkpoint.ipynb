# %%
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error,r2_score

# %%
dayDF = pd.DataFrame(pd.read_csv("./Bike-Sharing-Dataset/day.csv"))
hoursDF = pd.DataFrame(pd.read_csv("./Bike-Sharing-Dataset/hour.csv"))

# %%
dayDF.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
# 5           1  0.204348  0.233209  0.518261   0.089565      88        1518
# 6           2  0.196522  0.208839  0.498696   0.168726     148        1362
# 7           2  0.165000  0.162254  0.535833   0.266804      68         891
# 8           1  0.138333  0.116175  0.434167   0.361950      54         768
# 9           1  0.150833  0.150888  0.482917   0.223267      41        1280
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# 5  1606
# 6  1510
# 7   959
# 8   822
# 9  1321

# %%
hoursDF.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# 1           1  0.22  0.2727  0.80     0.0000       8          32   40
# 2           1  0.22  0.2727  0.80     0.0000       5          27   32
# 3           1  0.24  0.2879  0.75     0.0000       3          10   13
# 4           1  0.24  0.2879  0.75     0.0000       0           1    1
# 5           2  0.24  0.2576  0.75     0.0896       0           1    1
# 6           1  0.22  0.2727  0.80     0.0000       2           0    2
# 7           1  0.20  0.2576  0.86     0.0000       1           2    3
# 8           1  0.24  0.2879  0.75     0.0000       1           7    8
# 9           1  0.32  0.3485  0.76     0.0000       8           6   14

# %%
dayDF.shape
# Out:
# (731, 16)

# %%
hoursDF.shape
# Out:
# (17379, 17)

# %%
dayDF.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %%
hoursDF.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
dayDF.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hoursDF.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# Instant, dteday, yr are not needed as these features won't help in prediction

# %%
dayDF = dayDF.drop(['instant','dteday','yr'], axis=1)
hoursDF = hoursDF.drop(['instant','dteday','yr'], axis=1)

# %% [markdown]
# Some columns like season, mnth, hr, holiday, weekday, workingday, weathersit can be converted into categorical fields instead of numerical int64

# %%
hoursDF.dtypes
# Out:
# season          int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
dayDF.dtypes
# Out:
# season          int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
dayDF['season'] = dayDF.season.astype('category')
dayDF['mnth'] = dayDF.mnth.astype('category')
dayDF['holiday'] = dayDF.holiday.astype('category')
dayDF['weekday'] = dayDF.weekday.astype('category')
dayDF['workingday'] = dayDF.workingday.astype('category')
dayDF['weathersit'] = dayDF.weathersit.astype('category')

# %%
hoursDF['season'] = hoursDF.season.astype('category')
hoursDF['mnth'] = hoursDF.mnth.astype('category')
hoursDF['hr'] = hoursDF.hr.astype('category')
hoursDF['holiday'] = hoursDF.holiday.astype('category')
hoursDF['weekday'] = hoursDF.weekday.astype('category')
hoursDF['workingday'] = hoursDF.workingday.astype('category')
hoursDF['weathersit'] = hoursDF.weathersit.astype('category')

# %%
dayDF.isnull().any()
# Out:
# season        False
# mnth          False
# holiday       False
# weekday       False
# workingday    False
# weathersit    False
# temp          False
# atemp         False
# hum           False
# windspeed     False
# casual        False
# registered    False
# cnt           False
# dtype: bool

# %%
hoursDF.isnull().any()
# Out:
# season        False
# mnth          False
# hr            False
# holiday       False
# weekday       False
# workingday    False
# weathersit    False
# temp          False
# atemp         False
# hum           False
# windspeed     False
# casual        False
# registered    False
# cnt           False
# dtype: bool

# %%
dayDF.columns
# Out:
# Index(['season', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit',
#        'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
dayDF_season_mnth_DF = dayDF.groupby(['season','mnth'])['cnt'].sum().reset_index()

# %%
dayDF_season_mnth_DF
# Out:
#    season mnth     cnt
# 0       1    1  134933
# 1       1    2  151352
# 2       1    3  142065
# 3       1   12   42998
# 4       2    3   86855
# 5       2    4  269094
# 6       2    5  331686
# 7       2    6  230954
# 8       3    6  115388
# 9       3    7  344948
# 10      3    8  351194
# 11      3    9  249599
# 12      4    9   96392
# 13      4   10  322352
# 14      4   11  254831
# 15      4   12  168038

# %%
sea.set(style="whitegrid")

# %%
ax = sea.barplot(x="cnt", y="mnth", hue="season", data=dayDF_season_mnth_DF,palette="rocket")
ax.set(title="count of rentals grouped by month and season")
# Out:
# [Text(0.5,1,'count of rentals grouped by month and season')]

# %% [markdown]
# Rentals are high during season-2, season-3

# %% [markdown]
# Rentals occur mostly on Friday and Saturday

# %%
dayDF.groupby(['weekday'])['cnt'].sum().reset_index()
# Out:
#   weekday     cnt
# 0       0  444027
# 1       1  455503
# 2       2  469109
# 3       3  473048
# 4       4  485395
# 5       5  487790
# 6       6  477807

# %%
sea.set(style="whitegrid")

# %%
ax = sea.barplot(x="weekday", y="cnt", data=dayDF.groupby(['weekday'])['cnt'].sum().reset_index())
ax.set(title="Rentals during weekdays")
# Out:
# [Text(0.5,1,'Rentals during weekdays')]

# %%
sea.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(15,7))
ax = sea.pointplot(data=hoursDF[['hr',
                       'cnt',
                       'weekday']],
            x='hr', y='cnt',
            hue='weekday')

# %%
day_cor = dayDF.corr()

# %%
plt.figure(figsize=(15,10))
sea.heatmap(day_cor,annot=True)
plt.show()

# %% [markdown]
# When registered and casual result upto cnt, we can remove casual column. High correlation exists between temp and atemp, registered and cnt. So, we can remove atemp, registered, casual columns. Along with that, very low correlated column windspeed is also removed

# %%
hoursDF = hoursDF.drop(['atemp','registered','casual','windspeed'], axis=1)
hoursDF.corr()
# Out:
#           temp       hum       cnt
# temp  1.000000 -0.069881  0.404772
# hum  -0.069881  1.000000 -0.322911
# cnt   0.404772 -0.322911  1.000000

# %%
dayDF.describe()
# Out:
#              temp       atemp         hum   windspeed       casual  \
# count  731.000000  731.000000  731.000000  731.000000   731.000000
# mean     0.495385    0.474354    0.627894    0.190486   848.176471
# std      0.183051    0.162961    0.142429    0.077498   686.622488
# min      0.059130    0.079070    0.000000    0.022392     2.000000
# 25%      0.337083    0.337842    0.520000    0.134950   315.500000
# 50%      0.498333    0.486733    0.626667    0.180975   713.000000
# 75%      0.655417    0.608602    0.730209    0.233214  1096.000000
# max      0.861667    0.840896    0.972500    0.507463  3410.000000
#
#         registered          cnt
# count   731.000000   731.000000
# mean   3656.172367  4504.348837
# std    1560.256377  1937.211452
# min      20.000000    22.000000
# 25%    2497.000000  3152.000000
# 50%    3662.000000  4548.000000
# 75%    4776.500000  5956.000000
# max    6946.000000  8714.000000

# %%
from statsmodels.graphics.gofplots import qqplot
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
sea.distplot(dayDF['cnt'], ax=ax1)
ax.set(title="Distribution before log of count")
qqplot(dayDF['cnt'], line='s', ax=ax2)
ax.set(title="Theoretical quantiles")
# Out:
# C:\Users\Prady\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'Theoretical quantiles')]

# %%
hoursDF.describe()
# Out:
#                temp           hum           cnt
# count  17379.000000  17379.000000  17379.000000
# mean       0.496987      0.627229    189.463088
# std        0.192556      0.192930    181.387599
# min        0.020000      0.000000      1.000000
# 25%        0.340000      0.480000     40.000000
# 50%        0.500000      0.630000    142.000000
# 75%        0.660000      0.780000    281.000000
# max        1.000000      1.000000    977.000000

# %%
from statsmodels.graphics.gofplots import qqplot
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
sea.distplot(hoursDF['cnt'], ax=ax1)
ax.set(title="Distribution before log of count")
qqplot(hoursDF['cnt'], line='s', ax=ax2)
ax.set(title="Theoretical quantiles")
# Out:
# C:\Users\Prady\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'Theoretical quantiles')]

# %%
import math
hoursDF['cnt'] = hoursDF['cnt'].transform(lambda x: math.log(x))

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
sea.distplot(hoursDF['cnt'], ax=ax1)
ax.set(title="Distribution after log of count")
qqplot(hoursDF['cnt'], line='s', ax=ax2)
ax.set(title="Theoretical quantiles")
# Out:
# C:\Users\Prady\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'Theoretical quantiles')]

# %%
temp_data = hoursDF

def one_hot_encoding(df, column):       
    df = pd.concat([df, pd.get_dummies(df[column], prefix=column, drop_first=True)],axis=1)
    df = df.drop([column], axis=1)
    return df

category_columns = ['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']
for column in category_columns:
    temp_data = one_hot_encoding(temp_data, column)
    
hoursDF = temp_data

# %%
hoursDF.columns
# Out:
# Index(['temp', 'hum', 'cnt', 'season_2', 'season_3', 'season_4', 'mnth_2',
#        'mnth_3', 'mnth_4', 'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9',
#        'mnth_10', 'mnth_11', 'mnth_12', 'hr_1', 'hr_2', 'hr_3', 'hr_4', 'hr_5',
#        'hr_6', 'hr_7', 'hr_8', 'hr_9', 'hr_10', 'hr_11', 'hr_12', 'hr_13',
#        'hr_14', 'hr_15', 'hr_16', 'hr_17', 'hr_18', 'hr_19', 'hr_20', 'hr_21',
#        'hr_22', 'hr_23', 'holiday_1', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5', 'weekday_6', 'workingday_1', 'weathersit_2',
#        'weathersit_3', 'weathersit_4'],
#       dtype='object')

# %% [markdown]
# Linear Regression for target Variable "cnt" [for Hours Data Only]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train_X,test_X,train_Y,test_Y =  train_test_split(hoursDF[['temp','hum','season_2', 'season_3', 'season_4', 'mnth_2',
       'mnth_3', 'mnth_4', 'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9',
       'mnth_10', 'mnth_11', 'mnth_12', 'hr_1', 'hr_2', 'hr_3', 'hr_4', 'hr_5',
       'hr_6', 'hr_7', 'hr_8', 'hr_9', 'hr_10', 'hr_11', 'hr_12', 'hr_13',
       'hr_14', 'hr_15', 'hr_16', 'hr_17', 'hr_18', 'hr_19', 'hr_20', 'hr_21',
       'hr_22', 'hr_23', 'holiday_1', 'weekday_1', 'weekday_2', 'weekday_3',
       'weekday_4', 'weekday_5', 'weekday_6', 'workingday_1', 'weathersit_2',
       'weathersit_3', 'weathersit_4']],hoursDF['cnt'],test_size=0.33,random_state=19)

# %%
model_1 = LinearRegression()
model_1.fit(train_X,train_Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred_1=model_1.predict(test_X)

# %%
mse = mean_squared_error(test_Y,pred_1)
mse
# Out:
# 0.435369240691137

# %%
rmse = math.pow(mse,0.5)
rmse
# Out:
# 0.6598251591832014

# %% [markdown]
# Regression Score (coefficient of determination)

# %%
r2_value = r2_score(test_Y,pred_1)

# %%
r2_value
# Out:
# 0.8019656539901774

# %%
row = [i for i in range(0,test_Y.size)]
fig = plt.figure()
plt.plot(row,test_Y, color="red", linewidth=2.5,)
plt.plot(row,pred_1, color="green",  linewidth=2.5, linestyle="--")
fig.suptitle('Actual Count vs Predicted Count', fontsize=16)
plt.xlabel('row', fontsize=12)                            
plt.ylabel('count', fontsize=12)
# Out:
# Text(0,0.5,'count')
